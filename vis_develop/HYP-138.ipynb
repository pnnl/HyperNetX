# %% [markdown]
# # HYP-138
# Add the ability to change labels on Entities

# %%
# %load_ext autoreload
# %autoreload 2
import hypernetx as hnx

# %%
scenes = {
    0: ('FN', 'TH'),
    1: ('TH', 'JV'),
    2: ('BM', 'FN', 'JA'),
    3: ('JV', 'JU', 'CH', 'BM'),
    4: ('JU', 'CH', 'BR', 'CN', 'CC', 'JV', 'BM'),
    5: ('TH', 'GP'),
    6: ('GP', 'MP'),
    7: ('MA', 'GP')
}

H = hnx.Hypergraph(scenes)

# %% [markdown]
# ## With and without node labels

# %%
node_labels = {
    'BM': 'Monsieur Bamatabois',
    'BR': 'Brevet',
    'CC': 'Cochepaille',
    'CH': 'Champmathieu',
    'CN': 'Chenildieu',
    'FN': 'Fantine',
    'GP': 'George Pontmercy',
    'JA': 'Javert',
    'JU': 'Judge of Douai',
    'JV': 'Jean Valjean',
    'MA': 'Marius',
    'MP': 'Madame Pontmercy',
    'TH': 'Thénardier'
}

# %%
hnx.draw(H)
# Out:
# /Users/aren438/projects/HyperNetX/hypernetx/drawing/rubber_band.py:96: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   return .0125*np.median([pdist(np.vstack(map(pos.get, H.nodes))).max()

# %%
hnx.draw(H, node_labels=node_labels)

# %%
# test interaction with collapsing nodes
hnx.draw(H.collapse_nodes(), node_labels=node_labels)

# %% [markdown]
# ## With and without edge labels

# %%
edge_labels = {
    i: f'Scene {i}'
    for i in scenes
}

edge_labels
# Out:
# {0: 'Scene 0',
#  1: 'Scene 1',
#  2: 'Scene 2',
#  3: 'Scene 3',
#  4: 'Scene 4',
#  5: 'Scene 5',
#  6: 'Scene 6',
#  7: 'Scene 7'}

# %%
hnx.draw(H)

# %%
hnx.draw(H, edge_labels=edge_labels)
