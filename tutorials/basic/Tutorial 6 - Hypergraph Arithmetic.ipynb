# %%
#importing and installing packages
# %pip install hypernetx 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import hypernetx as hnx
import warnings
warnings.simplefilter('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning)
#set plotting parameters
TextSize = 15
# Out:
# Requirement already satisfied: hypernetx in /opt/anaconda3/lib/python3.11/site-packages (2.2.0)
# Requirement already satisfied: celluloid<0.3.0,>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from hypernetx) (0.2.0)
# Requirement already satisfied: igraph<0.12.0,>=0.11.4 in /opt/anaconda3/lib/python3.11/site-packages (from hypernetx) (0.11.5)
# Requirement already satisfied: networkx<4.0,>=3.3 in /opt/anaconda3/lib/python3.11/site-packages (from hypernetx) (3.3)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /opt/anaconda3/lib/python3.11/site-packages (from hypernetx) (2.2.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from hypernetx) (1.4.2)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from celluloid<0.3.0,>=0.2.0->hypernetx) (3.8.0)
# Requirement already satisfied: texttable>=1.6.2 in /opt/anaconda3/lib/python3.11/site-packages (from igraph<0.12.0,>=0.11.4->hypernetx) (1.7.0)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->hypernetx) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->hypernetx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->hypernetx) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=2.2.2->hypernetx) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.4.2->hypernetx) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.4.2->hypernetx) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.4.2->hypernetx) (2.2.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.2->hypernetx) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->celluloid<0.3.0,>=0.2.0->hypernetx) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Operations on Hypergraphs
#
# Here we demonstrate some basic hypergraph arithmetic including addition, subtraction, union, and intersection.

# %%
#plotting parameters to color edges for comparing and position layout
colors = plt.rcParams['axes.prop_cycle'].by_key()['color'][:4]
edge_color_dict = {'M1':colors[0], 'M2': colors[1], 'M3':colors[2], 'M4':colors[3]}

HG_pos = {
         'P1': (0.0, 0.5),
         'P2': (0.0, 0.0),
         'P3': (0.5, 0.0),
         'P4': (1.0, 0.0),
         'P5': (1.0, 0.5),
         'P6': (0.5, 0.5)}

# %%
#we start by defining our two hypergraphs for comparing

HG1 = {'M1': {'P4', 'P5'},
       'M2': {'P5', 'P6'},
       'M4': {'P1', 'P2'}}
H1 = hnx.Hypergraph(HG1)


HG2 = {'M1': {'P4', 'P5'},
       'M3': {'P2', 'P3', 'P4'},
       'M4': {'P1', 'P2', 'P3'}}
H2 = hnx.Hypergraph(HG2)

# %%
#visualize our two hypergraphs
plt.figure(figsize = (8,3))
gs = gridspec.GridSpec(1, 2)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# ## Addition

# %%
plt.figure(figsize = (12,3))
gs = gridspec.GridSpec(1, 3)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 2]) #plot time series
plt.title('$HG_1 + HG_2$')
hnx.draw(H1+H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # Subtraction

# %%
plt.figure(figsize = (12,3))
gs = gridspec.GridSpec(1, 3)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 2]) #plot time series
plt.title('$HG_1 - HG_2$')
hnx.draw(H1-H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()

# %%
plt.figure(figsize = (12,3))
gs = gridspec.GridSpec(1, 3)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 2]) #plot time series
plt.title('$HG_2 - HG_1$')
hnx.draw(H2-H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# ## Union

# %%
plt.figure(figsize = (12,3))
gs = gridspec.GridSpec(1, 3)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 2]) #plot time series
plt.title('$HG_1 \\cup HG_2$')
hnx.draw(H1.union(H2), pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # Intersection

# %%
plt.figure(figsize = (12,3))
gs = gridspec.GridSpec(1, 3)

ax = plt.subplot(gs[0, 0]) #plot time series
plt.title('$HG_1$')
hnx.draw(H1, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 1]) #plot time series
plt.title('$HG_2$')
hnx.draw(H2, pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

ax = plt.subplot(gs[0, 2]) #plot time series
plt.title('$HG_1 \\cap HG_2$')
hnx.draw(H1.intersection(H2), pos = HG_pos, edges_kwargs = {'edgecolors': edge_color_dict})

plt.subplots_adjust(wspace=0.5)
plt.show()
