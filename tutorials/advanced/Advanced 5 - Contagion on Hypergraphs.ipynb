# %%
# !pip install celluloid ##uncomment if not installed in your environment

# %% [markdown]
# ## Modeling Contagion with Hypergraphs
# This work is based on the paper [The effect of heterogeneity on hypergraph contagion models by Nicholas Landry](https://aip.scitation.org/doi/10.1063/5.0020034)
# The SIS and SIR simulations will each take several minutes to run.

# %%
import hypernetx as hnx
import hypernetx.algorithms.temporal.contagion as contagion
import matplotlib.pyplot as plt
import random
import time
import warnings 
warnings.simplefilter('ignore')

# %%
n = 1000 
m = 10000 

hyperedgeList = [random.sample(range(n), k=random.choice([2,3])) for i in range(m)]
H = hnx.Hypergraph(hyperedgeList, static=True)

# %% [markdown]
# ## Initialize simulation variables
# - $\tau$ is a dictionary of the infection rate for each hyperedge size
# - $\gamma$ is the healing rate
# - $t_{max}$ is the time at which to terminate the simulation if it hasn't already
# - $\Delta t$ is the time step size to use for the discrete time algorithm

# %%
tau = {2:0.01, 3:0.01}
gamma = 0.01
tmax = 100
dt = 1

# %% [markdown]
# ## Run the SIR epidemic simulations
# - The discrete SIR takes fixed steps in time and multiple infection/healing events can happen at each time step.
# - The Gillespie SIR algorithm takes steps in time exponentially distributed and at each step forward, a single event occurs
# - As $\Delta t\to 0$, the discrete time algorithm converges to the Gillespie algorithm.

# %%
start = time.time()
t1, S1, I1, R1 = contagion.discrete_SIR(H, tau, gamma, rho=0.1, tmin=0, tmax=tmax, dt=dt)
print(time.time() - start)
## ~15.358373165130615 sec

start = time.time()
t2, S2, I2, R2 = contagion.Gillespie_SIR(H, tau, gamma, rho=0.1, tmin=0, tmax=tmax)
print(time.time() - start)
## ~5.23570895195007 sec
# Out:
# 18.687098026275635
# 5.385437965393066

# %% [markdown]
# The Gillespie algorithm is much faster in many cases (and more accurate) than discrete-time algorithms because it doesn't consider events that don't happen. Instead, it calculates when the next event will occur and what event (infection, recovery, etc.) it will be.

# %% [markdown]
# ## Plot of the results
# - Dashed lines are the results from the discrete time algorithm
# - Solid lines are the results from the Gillespie algorithm
# - Plots of the numbers susceptible, infected, and recovered over time

# %%
plt.figure()
plt.plot(t1, S1, 'g--', label='S (Discrete)')
plt.plot(t1, I1, 'r--', label='I (Discrete)')
plt.plot(t1, R1, 'b--', label='R (Discrete)')
plt.plot(t2, S2, 'g-', label='S (Gillespie)')
plt.plot(t2, I2, 'r-', label='I (Gillespie)')
plt.plot(t2, R2, 'b-', label='R (Gillespie)')
plt.xlabel("Time", fontsize=14)
plt.ylabel("Number of people", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## SIS Model
# In this model, once individuals heal, they may become re-infected.

# %%
tau = {2:0.01, 3:0.01}
gamma = 0.01
tmax = 100
dt = 1
start = time.time()
t1, S1, I1 = contagion.discrete_SIS(H, tau, gamma, rho = 0.1, tmin = 0, tmax=tmax, dt=dt)
print(time.time() - start)
# ~680.240907907486 sec

start = time.time()
t2, S2, I2 = contagion.Gillespie_SIS(H, tau, gamma, rho = 0.1, tmin = 0, tmax=tmax)
print(time.time() - start)


# ~236.78710913658142 sec
# Out:
# 23.80088710784912
# 7.999640941619873

# %%
plt.figure()
plt.plot(t1, S1, 'g--', label='S (Discrete)')
plt.plot(t1, I1, 'r--', label='I (Discrete)')
plt.plot(t2, S2, 'g-', label='S (Gillespie)')
plt.plot(t2, I2, 'r-', label='I (Gillespie)')
plt.xlabel("Time", fontsize=14)
plt.ylabel("Number of people", fontsize=14)
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## Animation of SIR model

# %%
import hypernetx as hnx
import matplotlib.pyplot as plt
import random
import time
import numpy as np
from IPython.display import HTML

# %%
n = 100
m = 40

hyperedgeList = [random.sample(range(n), k=random.choice([2,3])) for i in range(m)]
H = hnx.Hypergraph(hyperedgeList, static=True)

# %%
tau = {2:2, 3:1}
gamma = 0.1

# %%
transition_events = contagion.discrete_SIR(H, tau, gamma, 
                                           rho=0.2, tmin=0, 
                                           tmax=50, dt=1, return_full_data=True)

# %%
for time, events in transition_events.items():
    if events:
        for event in events:
            if event[0] == 'R':
                print(f"At time {time}, {event[1]} recovered")
            elif event[0] == 'I' and event[2] is not None:
                print(f"At time {time}, {event[1]} was infected by {event[2]}")
# Out:
# At time 1, 24 was infected by 1
# At time 1, 70 was infected by 26
# At time 1, 2 was infected by 24
# At time 1, 30 was infected by 23
# At time 1, 39 was infected by 6
# At time 1, 58 was infected by 25
# At time 1, 26 was infected by 17
# At time 1, 21 was infected by 24
# At time 1, 41 was infected by 9
# At time 1, 62 was infected by 10
# At time 1, 99 was infected by 10
# At time 1, 32 was infected by 25
# At time 1, 51 was infected by 26
# At time 1, 16 was infected by 23
# At time 1, 59 recovered
# At time 1, 68 was infected by 28
# At time 2, 74 was infected by 2
# At time 2, 37 was infected by 3
# At time 2, 84 was infected by 3
# At time 2, 80 was infected by 4
# At time 2, 82 recovered
# At time 2, 79 was infected by 7
# At time 2, 99 recovered
# At time 2, 85 was infected by 11
# At time 2, 95 was infected by 16
# At time 2, 12 was infected by 16
# At time 2, 61 recovered
# At time 2, 29 was infected by 30
# At time 2, 18 was infected by 34
# At time 3, 2 recovered
# At time 3, 84 recovered
# At time 3, 50 was infected by 20
# At time 3, 41 recovered
# At time 3, 48 was infected by 15
# At time 3, 7 was infected by 15
# At time 3, 22 was infected by 39
# At time 3, 75 was infected by 29
# At time 3, 29 recovered
# At time 3, 93 was infected by 32
# At time 3, 18 recovered
# At time 3, 91 was infected by 37
# At time 4, 94 recovered
# At time 4, 24 recovered
# At time 4, 33 was infected by 5
# At time 4, 86 was infected by 5
# At time 4, 8 was infected by 13
# At time 4, 57 recovered
# At time 4, 46 was infected by 19
# At time 4, 87 was infected by 31
# At time 4, 96 was infected by 36
# At time 5, 50 recovered
# At time 5, 39 recovered
# At time 5, 1 was infected by 12
# At time 5, 48 recovered
# At time 5, 51 recovered
# At time 5, 16 recovered
# At time 5, 88 recovered
# At time 6, 30 recovered
# At time 6, 27 recovered
# At time 6, 11 was infected by 21
# At time 6, 76 was infected by 21
# At time 7, 21 recovered
# At time 7, 22 recovered
# At time 8, 70 recovered
# At time 8, 54 recovered
# At time 8, 0 recovered
# At time 9, 80 recovered
# At time 9, 86 recovered
# At time 9, 7 recovered
# At time 10, 58 recovered
# At time 10, 85 recovered
# At time 11, 79 recovered
# At time 12, 91 recovered
# At time 13, 62 recovered
# At time 13, 95 recovered
# At time 14, 37 recovered
# At time 14, 11 recovered
# At time 16, 68 recovered
# At time 17, 33 recovered
# At time 17, 26 recovered
# At time 17, 1 recovered
# At time 17, 12 recovered
# At time 17, 75 recovered
# At time 17, 87 recovered
# At time 17, 93 recovered
# At time 18, 45 recovered
# At time 18, 46 recovered
# At time 18, 96 recovered
# At time 19, 74 recovered
# At time 20, 76 recovered
# At time 22, 64 recovered
# At time 23, 32 recovered
# At time 23, 8 recovered

# %%
node_state_color_dict = {"S":"green", "I":"red", "R":"blue"}
edge_state_color_dict = {"S":(0, 1, 0, 0.3), "I":(1, 0, 0, 0.3), 
                        "R":(0, 0, 1, 0.3), "OFF": (1, 1, 1, 0)}

fps = 1

fig = plt.figure()
animation = contagion.contagion_animation(fig, H, transition_events, 
                                          node_state_color_dict, 
                                          edge_state_color_dict, node_radius=1, 
                                          fps=fps)
plt.show()

# %%
HTML(animation.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc4b318ac24cf4f31b5e29cdb121b96fb">
#   <div class="anim-controls">
#     <input id="_anim_sliderc4b318ac24cf4f31b5e29cdb121b96fb" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc4b318ac24cf4f31b5e29cdb121b96fb.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc4b318ac24cf4f31b5e29cdb121b96fb.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc4b318ac24cf4f31b5e29cdb121b96fb"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c4b318ac24cf4f31b5e29cdb121b96fb"
#              >
#       <label for="_anim_radio1_c4b318ac24cf4f31b5e29cdb121b96fb">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c4b318ac24cf4f31b5e29cdb121b96fb"
#              checked>
#       <label for="_anim_radio2_c4b318ac24cf4f31b5e29cdb121b96fb">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c4b318ac24cf4f31b5e29cdb121b96fb"
#              >
#       <label for="_anim_radio3_c4b318ac24cf4f31b5e29cdb121b96fb">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc4b318ac24cf4f31b5e29cdb121b96fb";
#     var slider_id = "_anim_sliderc4b318ac24cf4f31b5e29cdb121b96fb";
#     var loop_select_id = "_anim_loop_selectc4b318ac24cf4f31b5e29cdb121b96fb";
#     var frames = new Array(24);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy81sbWrAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAEAAElEQ

# %% [markdown]
# ## Animation of the SIS model

# %%
transition_events2 = contagion.discrete_SIS(H, tau, gamma, rho=0.2, tmin=0, tmax=50, dt=1, return_full_data=True)

# %%
for time, events in transition_events2.items():
    if events:
        for event in events:
            if event[0] == 'S':
                print(f"At time {time}, {event[1]} recovered")
            elif event[0] == 'I' and event[2] is not None:
                print(f"At time {time}, {event[1]} was infected by {event[2]}")
# Out:
# At time 1, 65 was infected by 0
# At time 1, 5 was infected by 0
# At time 1, 70 was infected by 26
# At time 1, 2 was infected by 24
# At time 1, 84 was infected by 15
# At time 1, 30 was infected by 8
# At time 1, 82 was infected by 38
# At time 1, 58 was infected by 7
# At time 1, 26 was infected by 7
# At time 1, 99 was infected by 10
# At time 1, 45 was infected by 10
# At time 1, 48 was infected by 15
# At time 1, 95 recovered
# At time 1, 51 was infected by 16
# At time 1, 12 was infected by 16
# At time 1, 57 was infected by 24
# At time 1, 22 was infected by 39
# At time 1, 55 was infected by 22
# At time 1, 69 recovered
# At time 1, 68 was infected by 28
# At time 1, 75 was infected by 29
# At time 1, 18 was infected by 35
# At time 2, 65 recovered
# At time 2, 24 was infected by 33
# At time 2, 74 was infected by 2
# At time 2, 37 was infected by 3
# At time 2, 80 was infected by 4
# At time 2, 39 was infected by 6
# At time 2, 82 recovered
# At time 2, 27 was infected by 18
# At time 2, 99 recovered
# At time 2, 32 was infected by 25
# At time 2, 48 recovered
# At time 2, 8 was infected by 13
# At time 2, 95 was infected by 16
# At time 2, 46 was infected by 19
# At time 2, 69 was infected by 22
# At time 2, 61 was infected by 23
# At time 2, 16 was infected by 23
# At time 2, 88 was infected by 25
# At time 2, 29 was infected by 30
# At time 2, 87 was infected by 31
# At time 2, 93 was infected by 32
# At time 2, 96 was infected by 36
# At time 3, 65 was infected by 0
# At time 3, 47 recovered
# At time 3, 94 was infected by 1
# At time 3, 82 was infected by 6
# At time 3, 58 recovered
# At time 3, 41 was infected by 9
# At time 3, 99 was infected by 10
# At time 3, 85 was infected by 11
# At time 3, 48 was infected by 13
# At time 3, 8 recovered
# At time 3, 51 recovered
# At time 3, 61 recovered
# At time 3, 16 recovered
# At time 3, 59 was infected by 27
# At time 3, 29 recovered
# At time 4, 47 was infected by 0
# At time 4, 94 recovered
# At time 4, 70 recovered
# At time 4, 50 was infected by 20
# At time 4, 58 was infected by 7
# At time 4, 41 recovered
# At time 4, 8 was infected by 13
# At time 4, 51 was infected by 16
# At time 4, 54 recovered
# At time 4, 22 recovered
# At time 4, 55 recovered
# At time 4, 69 recovered
# At time 4, 61 was infected by 23
# At time 4, 16 was infected by 23
# At time 4, 75 recovered
# At time 4, 29 was infected by 30
# At time 4, 91 recovered
# At time 5, 94 was infected by 1
# At time 5, 70 was infected by 2
# At time 5, 33 was infected by 5
# At time 5, 86 was infected by 5
# At time 5, 41 was infected by 9
# At time 5, 54 was infected by 17
# At time 5, 22 was infected by 19
# At time 5, 61 recovered
# At time 5, 75 was infected by 29
# At time 5, 96 recovered
# At time 5, 91 was infected by 37
# At time 6, 84 recovered
# At time 6, 86 recovered
# At time 6, 27 recovered
# At time 6, 99 recovered
# At time 6, 85 recovered
# At time 6, 1 was infected by 12
# At time 6, 61 was infected by 23
# At time 6, 96 was infected by 36
# At time 7, 84 was infected by 3
# At time 7, 86 was infected by 5
# At time 7, 27 was infected by 9
# At time 7, 62 recovered
# At time 7, 99 was infected by 10
# At time 7, 85 was infected by 11
# At time 7, 1 recovered
# At time 7, 7 recovered
# At time 7, 95 recovered
# At time 7, 11 was infected by 21
# At time 7, 76 was infected by 21
# At time 7, 61 recovered
# At time 7, 96 recovered
# At time 8, 5 recovered
# At time 8, 30 recovered
# At time 8, 58 recovered
# At time 8, 62 was infected by 10
# At time 8, 1 was infected by 12
# At time 8, 7 was infected by 15
# At time 8, 95 was infected by 16
# At time 8, 22 recovered
# At time 8, 76 recovered
# At time 8, 61 was infected by 23
# At time 8, 64 recovered
# At time 8, 93 recovered
# At time 8, 18 recovered
# At time 8, 96 was infected by 36
# At time 9, 5 was infected by 0
# At time 9, 70 recovered
# At time 9, 37 recovered
# At time 9, 30 was infected by 4
# At time 9, 86 recovered
# At time 9, 58 was infected by 7
# At time 9, 99 recovered
# At time 9, 54 recovered
# At time 9, 22 was infected by 19
# At time 9, 76 was infected by 21
# At time 9, 64 was infected by 26
# At time 9, 93 was infected by 32
# At time 9, 18 was infected by 34
# At time 10, 47 recovered
# At time 10, 70 was infected by 2
# At time 10, 37 was infected by 3
# At time 10, 86 was infected by 5
# At time 10, 39 recovered
# At time 10, 27 recovered
# At time 10, 62 recovered
# At time 10, 99 was infected by 10
# At time 10, 1 recovered
# At time 10, 8 recovered
# At time 10, 54 was infected by 17
# At time 10, 75 recovered
# At time 11, 5 recovered
# At time 11, 47 was infected by 0
# At time 11, 39 was infected by 6
# At time 11, 27 was infected by 9
# At time 11, 62 was infected by 10
# At time 11, 99 recovered
# At time 11, 1 was infected by 12
# At time 11, 8 was infected by 13
# At time 11, 57 recovered
# At time 11, 75 was infected by 29
# At time 12, 5 was infected by 0
# At time 12, 33 recovered
# At time 12, 86 recovered
# At time 12, 99 was infected by 10
# At time 12, 32 recovered
# At time 12, 85 recovered
# At time 12, 57 was infected by 18
# At time 12, 64 recovered
# At time 12, 68 recovered
# At time 12, 93 recovered
# At time 13, 70 recovered
# At time 13, 33 was infected by 5
# At time 13, 86 was infected by 5
# At time 13, 32 was infected by 11
# At time 13, 85 was infected by 11
# At time 13, 64 was infected by 26
# At time 13, 68 was infected by 28
# At time 13, 87 recovered
# At time 13, 93 was infected by 32
# At time 14, 70 was infected by 2
# At time 14, 80 recovered
# At time 14, 30 recovered
# At time 14, 39 recovered
# At time 14, 45 recovered
# At time 14, 87 was infected by 31
# At time 14, 93 recovered
# At time 15, 30 was infected by 8
# At time 15, 39 was infected by 6
# At time 15, 58 recovered
# At time 15, 45 was infected by 10
# At time 15, 32 recovered
# At time 15, 93 was infected by 32
# At time 15, 91 recovered
# At time 16, 80 was infected by 4
# At time 16, 30 recovered
# At time 16, 58 was infected by 7
# At time 16, 41 recovered
# At time 16, 45 recovered
# At time 16, 32 was infected by 11
# At time 16, 54 recovered
# At time 16, 76 recovered
# At time 16, 93 recovered
# At time 16, 96 recovered
# At time 16, 91 was infected by 37
# At time 17, 74 recovered
# At time 17, 30 was infected by 4
# At time 17, 41 was infected by 9
# At time 17, 45 was infected by 10
# At time 17, 54 was infected by 17
# At time 17, 22 recovered
# At time 17, 76 was infected by 21
# At time 17, 87 recovered
# At time 17, 93 was infected by 32
# At time 17, 96 was infected by 36
# At time 18, 94 recovered
# At time 18, 74 was infected by 2
# At time 18, 45 recovered
# At time 18, 12 recovered
# At time 18, 22 was infected by 19
# At time 18, 76 recovered
# At time 18, 16 recovered
# At time 18, 0 recovered
# At time 18, 75 recovered
# At time 18, 87 was infected by 31
# At time 18, 18 recovered
# At time 19, 94 was infected by 1
# At time 19, 79 recovered
# At time 19, 58 recovered
# At time 19, 45 was infected by 10
# At time 19, 85 recovered
# At time 19, 12 was infected by 16
# At time 19, 76 was infected by 21
# At time 19, 16 was infected by 23
# At time 19, 0 was infected by 28
# At time 19, 75 was infected by 29
# At time 19, 29 recovered
# At time 19, 18 was infected by 34
# At time 20, 24 recovered
# At time 20, 84 recovered
# At time 20, 30 recovered
# At time 20, 79 was infected by 7
# At time 20, 58 was infected by 7
# At time 20, 85 was infected by 11
# At time 20, 29 was infected by 30
# At time 20, 18 recovered
# At time 21, 24 was infected by 1
# At time 21, 74 recovered
# At time 21, 84 was infected by 3
# At time 21, 30 was infected by 4
# At time 21, 57 recovered
# At time 21, 11 recovered
# At time 21, 76 recovered
# At time 21, 64 recovered
# At time 21, 18 was infected by 34
# At time 22, 74 was infected by 2
# At time 22, 84 recovered
# At time 22, 99 recovered
# At time 22, 54 recovered
# At time 22, 57 was infected by 18
# At time 22, 46 recovered
# At time 22, 11 was infected by 21
# At time 22, 76 was infected by 21
# At time 22, 16 recovered
# At time 22, 64 was infected by 26
# At time 23, 84 was infected by 3
# At time 23, 99 was infected by 10
# At time 23, 54 was infected by 17
# At time 23, 46 was infected by 19
# At time 23, 16 was infected by 23
# At time 24, 80 recovered
# At time 24, 46 recovered
# At time 24, 18 recovered
# At time 24, 91 recovered
# At time 25, 5 recovered
# At time 25, 94 recovered
# At time 25, 80 was infected by 4
# At time 25, 48 recovered
# At time 25, 95 recovered
# At time 25, 46 was infected by 19
# At time 25, 76 recovered
# At time 25, 88 recovered
# At time 25, 68 recovered
# At time 25, 18 was infected by 34
# At time 25, 96 recovered
# At time 25, 91 was infected by 37
# At time 26, 5 was infected by 0
# At time 26, 94 was infected by 1
# At time 26, 82 recovered
# At time 26, 45 recovered
# At time 26, 85 recovered
# At time 26, 48 was infected by 13
# At time 26, 8 recovered
# At time 26, 95 was infected by 16
# At time 26, 51 recovered
# At time 26, 11 recovered
# At time 26, 76 was infected by 21
# At time 26, 88 was infected by 25
# At time 26, 68 was infected by 28
# At time 26, 96 was infected by 36
# At time 27, 94 recovered
# At time 27, 2 recovered
# At time 27, 82 was infected by 6
# At time 27, 45 was infected by 10
# At time 27, 85 was infected by 11
# At time 27, 8 was infected by 13
# At time 27, 51 was infected by 16
# At time 27, 54 recovered
# At time 27, 11 was infected by 21
# At time 27, 87 recovered
# At time 28, 94 was infected by 1
# At time 28, 2 was infected by 3
# At time 28, 80 recovered
# At time 28, 7 recovered
# At time 28, 54 was infected by 17
# At time 28, 29 recovered
# At time 28, 87 was infected by 31
# At time 29, 65 recovered
# At time 29, 94 recovered
# At time 29, 80 was infected by 4
# At time 29, 50 recovered
# At time 29, 62 recovered
# At time 29, 45 recovered
# At time 29, 85 recovered
# At time 29, 7 was infected by 15
# At time 29, 57 recovered
# At time 29, 11 recovered
# At time 29, 29 was infected by 30
# At time 29, 87 recovered
# At time 30, 65 was infected by 0
# At time 30, 94 was infected by 1
# At time 30, 50 was infected by 5
# At time 30, 79 recovered
# At time 30, 26 recovered
# At time 30, 62 was infected by 10
# At time 30, 45 was infected by 10
# At time 30, 85 was infected by 11
# At time 30, 8 recovered
# At time 30, 95 recovered
# At time 30, 54 recovered
# At time 30, 57 was infected by 18
# At time 30, 11 was infected by 21
# At time 30, 87 was infected by 31
# At time 30, 93 recovered
# At time 30, 91 recovered
# At time 31, 24 recovered
# At time 31, 79 was infected by 7
# At time 31, 58 recovered
# At time 31, 26 was infected by 7
# At time 31, 45 recovered
# At time 31, 8 was infected by 13
# At time 31, 95 was infected by 16
# At time 31, 51 recovered
# At time 31, 12 recovered
# At time 31, 54 was infected by 38
# At time 31, 93 was infected by 32
# At time 31, 91 was infected by 37
# At time 32, 24 was infected by 1
# At time 32, 58 was infected by 7
# At time 32, 27 recovered
# At time 32, 45 was infected by 10
# At time 32, 51 was infected by 16
# At time 32, 12 was infected by 16
# At time 32, 59 recovered
# At time 32, 29 recovered
# At time 32, 93 recovered
# At time 33, 47 recovered
# At time 33, 80 recovered
# At time 33, 27 was infected by 9
# At time 33, 61 recovered
# At time 33, 59 was infected by 27
# At time 33, 29 was infected by 30
# At time 33, 87 recovered
# At time 33, 93 was infected by 32
# At time 34, 47 was infected by 0
# At time 34, 80 was infected by 4
# At time 34, 62 recovered
# At time 34, 1 recovered
# At time 34, 95 recovered
# At time 34, 54 recovered
# At time 34, 22 recovered
# At time 34, 61 was infected by 23
# At time 34, 87 was infected by 31
# At time 34, 18 recovered
# At time 35, 30 recovered
# At time 35, 62 was infected by 10
# At time 35, 1 was infected by 12
# At time 35, 48 recovered
# At time 35, 8 recovered
# At time 35, 95 was infected by 16
# At time 35, 54 was infected by 17
# At time 35, 22 was infected by 19
# At time 35, 18 was infected by 34
# At time 36, 74 recovered
# At time 36, 30 was infected by 4
# At time 36, 82 recovered
# At time 36, 1 recovered
# At time 36, 48 was infected by 15
# At time 36, 51 recovered
# At time 36, 11 recovered
# At time 36, 75 recovered
# At time 37, 74 was infected by 2
# At time 37, 37 recovered
# At time 37, 84 recovered
# At time 37, 80 recovered
# At time 37, 50 recovered
# At time 37, 82 was infected by 6
# At time 37, 1 was infected by 12
# At time 37, 8 was infected by 13
# At time 37, 51 was infected by 16
# At time 37, 11 was infected by 21
# At time 37, 59 recovered
# At time 37, 0 recovered
# At time 37, 75 was infected by 29
# At time 38, 37 was infected by 3
# At time 38, 84 was infected by 3
# At time 38, 80 was infected by 4
# At time 38, 50 was infected by 5
# At time 38, 82 recovered
# At time 38, 21 recovered
# At time 38, 62 recovered
# At time 38, 57 recovered
# At time 38, 59 was infected by 27
# At time 38, 0 was infected by 28
# At time 38, 29 recovered
# At time 38, 91 recovered
# At time 39, 37 recovered
# At time 39, 84 recovered
# At time 39, 82 was infected by 6
# At time 39, 58 recovered
# At time 39, 21 was infected by 8
# At time 39, 62 was infected by 10
# At time 39, 45 recovered
# At time 39, 12 recovered
# At time 39, 57 was infected by 18
# At time 39, 22 recovered
# At time 39, 0 recovered
# At time 39, 29 was infected by 30
# At time 39, 91 was infected by 37
# At time 40, 24 recovered
# At time 40, 74 recovered
# At time 40, 37 was infected by 3
# At time 40, 84 was infected by 3
# At time 40, 33 recovered
# At time 40, 58 was infected by 7
# At time 40, 45 was infected by 10
# At time 40, 85 recovered
# At time 40, 1 recovered
# At time 40, 12 was infected by 16
# At time 40, 22 was infected by 19
# At time 40, 88 recovered
# At time 40, 0 was infected by 28
# At time 40, 87 recovered
# At time 40, 91 recovered
# At time 41, 24 was infected by 1
# At time 41, 70 recovered
# At time 41, 74 was infected by 2
# At time 41, 33 was infected by 5
# At time 41, 85 was infected by 11
# At time 41, 1 was infected by 21
# At time 41, 8 recovered
# At time 41, 88 was infected by 25
# At time 41, 68 recovered
# At time 41, 87 was infected by 31
# At time 41, 91 was infected by 37
# At time 42, 24 recovered
# At time 42, 70 was infected by 2
# At time 42, 8 was infected by 13
# At time 42, 95 recovered
# At time 42, 54 recovered
# At time 42, 68 was infected by 28
# At time 43, 5 recovered
# At time 43, 24 was infected by 1
# At time 43, 30 recovered
# At time 43, 32 recovered
# At time 43, 1 recovered
# At time 43, 95 was infected by 16
# At time 43, 54 was infected by 17
# At time 43, 57 recovered
# At time 44, 5 was infected by 0
# At time 44, 70 recovered
# At time 44, 30 was infected by 4
# At time 44, 33 recovered
# At time 44, 79 recovered
# At time 44, 62 recovered
# At time 44, 32 was infected by 11
# At time 44, 1 was infected by 12
# At time 44, 57 was infected by 18
# At time 45, 65 recovered
# At time 45, 70 was infected by 2
# At time 45, 84 recovered
# At time 45, 33 was infected by 5
# At time 45, 79 was infected by 7
# At time 45, 62 was infected by 10
# At time 45, 59 recovered
# At time 46, 65 was infected by 0
# At time 46, 47 recovered
# At time 46, 84 was infected by 3
# At time 46, 79 recovered
# At time 46, 32 recovered
# At time 46, 11 recovered
# At time 46, 59 was infected by 27
# At time 47, 47 was infected by 0
# At time 47, 24 recovered
# At time 47, 74 recovered
# At time 47, 79 was infected by 7
# At time 47, 32 was infected by 11
# At time 47, 1 recovered
# At time 47, 11 was infected by 21
# At time 47, 18 recovered
# At time 48, 24 was infected by 1
# At time 48, 74 was infected by 2
# At time 48, 30 recovered
# At time 48, 58 recovered
# At time 48, 1 was infected by 12
# At time 48, 22 recovered
# At time 48, 64 recovered
# At time 48, 68 recovered
# At time 48, 18 was infected by 34
# At time 49, 65 recovered
# At time 49, 30 was infected by 4
# At time 49, 58 was infected by 7
# At time 49, 48 recovered
# At time 49, 54 recovered
# At time 49, 22 was infected by 19
# At time 49, 16 recovered
# At time 49, 64 was infected by 26
# At time 49, 68 was infected by 28
# At time 50, 65 was infected by 0
# At time 50, 2 recovered
# At time 50, 30 recovered
# At time 50, 48 was infected by 13
# At time 50, 54 was infected by 17
# At time 50, 16 was infected by 23
# At time 50, 96 recovered

# %%
node_state_color_dict = {"S":"green", "I":"red", "R":"blue"}
edge_state_color_dict = {"S":(0, 1, 0, 0.3), "I":(1, 0, 0, 0.3), 
                         "R":(0, 0, 1, 0.3), "OFF": (1, 1, 1, 0)}

fps = 1

animation2 = contagion.contagion_animation(fig, H, 
                                           transition_events2, 
                                           node_state_color_dict, 
                                           edge_state_color_dict, 
                                           node_radius=1, fps=fps)
plt.show()

# %%
HTML(animation2.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img857cb49200ae492d94d8fb18c6f2550b">
#   <div class="anim-controls">
#     <input id="_anim_slider857cb49200ae492d94d8fb18c6f2550b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim857cb49200ae492d94d8fb18c6f2550b.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim857cb49200ae492d94d8fb18c6f2550b.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim857cb49200ae492d94d8fb18c6f2550b.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim857cb49200ae492d94d8fb18c6f2550b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim857cb49200ae492d94d8fb18c6f2550b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim857cb49200ae492d94d8fb18c6f2550b.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim857cb49200ae492d94d8fb18c6f2550b.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim857cb49200ae492d94d8fb18c6f2550b.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim857cb49200ae492d94d8fb18c6f2550b.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim857cb49200ae492d94d8fb18c6f2550b.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select857cb49200ae492d94d8fb18c6f2550b"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_857cb49200ae492d94d8fb18c6f2550b"
#              >
#       <label for="_anim_radio1_857cb49200ae492d94d8fb18c6f2550b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_857cb49200ae492d94d8fb18c6f2550b"
#              checked>
#       <label for="_anim_radio2_857cb49200ae492d94d8fb18c6f2550b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_857cb49200ae492d94d8fb18c6f2550b"
#              >
#       <label for="_anim_radio3_857cb49200ae492d94d8fb18c6f2550b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img857cb49200ae492d94d8fb18c6f2550b";
#     var slider_id = "_anim_slider857cb49200ae492d94d8fb18c6f2550b";
#     var loop_select_id = "_anim_loop_select857cb49200ae492d94d8fb18c6f2550b";
#     var frames = new Array(51);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMCwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy81sbWrAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAADhwElEQ
