# %% [markdown]
# # Laplacians and Clustering
#
# <img src="../images/clus_workflow.png" width="850">
#
# Tutorial for hypergraph clustering utilizing random-walk based Laplacians. The hypergraph may be weighted or unweighted.
# The optional weights are associated with each **vertex-hyperedge pair**, sometimes referred to as "edge-dependent vertex weights" or "cell weights" of the incidence matrix. If unweighted, the underlying random walk is equivalent to a weighted random walk on the clique expansion (i.e. 2-section, one-mode projection) of the hypergraph. If weights are specified, the random walk isn't necessarily reversible, which implies it cannot be characterized as any random walk on an undirected graph. For more background on Laplacian-based hypergraph clustering, see
#
# Hayashi, K., Aksoy, S. G., Park, C. H., & Park, H.
# Hypergraph random walks, laplacians, and clustering.
# In Proceedings of CIKM 2020, (2020): 495-504.
#
# and the references contained therein. Feel free to direct inquries concerning this tutorial to Sinan Aksoy, sinan.aksoy@pnnl.gov

# %%
import hypernetx as hnx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import warnings 
warnings.simplefilter('ignore')

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import coo_matrix
from pprint import pprint

# %% [markdown]
# # Unweighted hypergraph clustering on LesMis
#
# A toy example of unweighted hypergraph clustering characters in the LesMis example based on scene co-occurance.

# %%
scenes = {
    0: ('FN', 'TH'),
    1: ('TH', 'JV'),
    2: ('BM', 'FN', 'JA'),
    3: ('JV', 'JU', 'CH', 'BM'),
    4: ('JU', 'CH', 'BR', 'CN', 'CC', 'JV', 'BM'),
    5: ('TH', 'GP'),
    6: ('GP', 'MP'),
    7: ('MA', 'GP')
}

H = hnx.Hypergraph(scenes)
clusters = hnx.spec_clus(H,3) #3 clusters
clusters
# Out:
# {0: ['FN', 'JA', 'TH'],
#  1: ['BM', 'BR', 'CC', 'CH', 'CN', 'JU', 'JV'],
#  2: ['GP', 'MA', 'MP']}

# %%
colors = ['r','g','b']
node_colors = dict()
for k,v in clusters.items():
    node_colors.update({vv:colors[k] for vv in v})
hnx.draw(H,nodes_kwargs={'color':node_colors})

# %% [markdown]
# # Weighted hypergraph clustering
#
# Hypergraph clustering on term-document data using tf-idf as cell weights. In this example, we use the 20newsgroups dataset:
#
# https://scikit-learn.org/0.19/datasets/twenty_newsgroups.html
#
# and consider documents falling into two subcategories. We form a static hypergraph with 787 documents as vertices, 20,868 terms as hyperedges, and tf-idf as vertex-hyperedge (i.e. cell) weights. We then form the normalized Laplacian and apply the spectral clustering algorithm as defined by "RDC-Spec" (Algorithm 1) in:
#
# Hayashi, K., Aksoy, S. G., Park, C. H., & Park, H.
# Hypergraph random walks, laplacians, and clustering.
# In Proceedings of CIKM 2020, (2020): 495-504.
#
# We plot the proportions of the document subcategories within each output cluster.

# %%
#list possible categories to choose from
all_categories = np.array((fetch_20newsgroups(subset='test').target_names))
pprint(list(enumerate(all_categories)))
# Out:
# [(0, 'alt.atheism'),
#  (1, 'comp.graphics'),
#  (2, 'comp.os.ms-windows.misc'),
#  (3, 'comp.sys.ibm.pc.hardware'),
#  (4, 'comp.sys.mac.hardware'),
#  (5, 'comp.windows.x'),
#  (6, 'misc.forsale'),
#  (7, 'rec.autos'),
#  (8, 'rec.motorcycles'),
#  (9, 'rec.sport.baseball'),
#  (10, 'rec.sport.hockey'),
#  (11, 'sci.crypt'),
#  (12, 'sci.electronics'),
#  (13, 'sci.med'),
#  (14, 'sci.space'),
#  (15, 'soc.religion.christian'),
#  (16, 'talk.politics.guns'),
#  (17, 'talk.politics.mideast'),
#  (18, 'talk.politics.misc'),
#  (19, 'talk.religion.misc')]

# %%
#select categories of documents to be clustered
categories = all_categories[[1,15]]
twenty_train = fetch_20newsgroups(subset='test',
                                  categories=categories, shuffle=True, random_state=42)

# %%
#record categories of documents
doc_types=dict()
for i,x in enumerate(twenty_train.filenames):
    doc_types[i]=x.split('/')[-2]

doc_types
# Out:
# {0: 'soc.religion.christian',
#  1: 'soc.religion.christian',
#  2: 'soc.religion.christian',
#  3: 'comp.graphics',
#  4: 'comp.graphics',
#  5: 'comp.graphics',
#  6: 'soc.religion.christian',
#  7: 'soc.religion.christian',
#  8: 'comp.graphics',
#  9: 'soc.religion.christian',
#  10: 'soc.religion.christian',
#  11: 'comp.graphics',
#  12: 'soc.religion.christian',
#  13: 'soc.religion.christian',
#  14: 'soc.religion.christian',
#  15: 'soc.religion.christian',
#  16: 'soc.religion.christian',
#  17: 'comp.graphics',
#  18: 'comp.graphics',
#  19: 'comp.graphics',
#  20: 'soc.religion.christian',
#  21: 'comp.graphics',
#  22: 'comp.graphics',
#  23: 'comp.graphics',
#  24: 'comp.graphics',
#  25: 'soc.religion.christian',
#  26: 'comp.graphics',
#  27: 'soc.religion.christian',
#  28: 'comp.graphics',
#  29: 'soc.religion.christian',
#  30: 'soc.religion.christian',
#  31: 'soc.religion.christian',
#  32: 'comp.graphics',
#  33: 'comp.graphics',
#  34: 'soc.religion.christian',
#  35: 'comp.graphics',
#  36: 'comp.graphics',
#  37: 'comp.graphics',
#  38: 'comp.graphics',
#  39: 'comp.graphics',
#  40: 'soc.religion.christian',
#  41: 'soc.religion.christian',
#  42: 'comp.graphics',
#  43: 'comp.graphics',
#  44: 'comp.graphics',
#  45: 'comp.graphics',
#  46: 'comp.graphics',
#  47: 'soc.religion.christian',
#  48: 'comp.graphics',
#  49: 'comp.graphics',
#  50: 'comp.graphics',
#  51: 'soc.religion.christian',
#  52: 'comp.graphics',
#  53: 'comp.graphics',
#  54: 'comp.graphics',
#  55: 'soc.religion.christian',
#  56: 'soc.religion.christian',
#  57: 'comp.graphics',
#  58: 'soc.religion.christian',
#  59: 'soc.religion.christian',
#  60: 'soc.religion.christian',
#  61: 'comp.graphics',
#  62: 'comp.graphics',
#  63: 'comp.graphics',
#  64: 'soc.religion.christian',
#  65: 'comp.graphics',
#  66: 'comp.graphics',
#  67: 'comp.graphics',
#  68: 'comp.graphics',
#  69: 'comp.graphics',
#  70: 'comp.graphics',
#  71: 'soc.religion.christian',
#  72: 'soc.religion.christian',
#  73: 'soc.religion.christian',
#  74: 'comp.graphics',
#  75: 'comp.graphics',
#  76: 'comp.graphics',
#  77: 'comp.graphics',
#  78: 'comp.graphics',
#  79: 'soc.religion.christian',
#  80: 'soc.religion.christian',
#  81: 'soc.religion.christian',
#  82: 'comp.graphics',
#  83: 'comp.graphics',
#  84: 'soc.religion.christian',
#  85: 'soc.religion.christian',
#  86: 'comp.graphics',
#  87: 'soc.religion.christian',
#  88: 'soc.religion.christian',
#  89: 'comp.graphics',
#  90: 'comp.graphics',
#  91: 'soc.religion.christian',
#  92: 'soc.religion.christian',
#  93: 'comp.graphics',
#  94: 'comp.graphics',
#  95: 'soc.religion.christian',
#  96: 'comp.graphics',
#  97: 'soc.religion.christian',
#  98: 'soc.religion.christian',
#  99: 'soc.religion.christian',
#  100: 'comp.graphics',
#  101: 'comp.graphics',
#  102: 'comp.graphics',
#  103: 'soc.religion.christian',
#  104: 'comp.graphics',
#  105: 'soc.religion.christian',
#  106: 'soc.religion.christian',
#  107: 'comp.graphics',
#  108: 'soc.religion.christian',
#  109: 'comp.graphics',
#  110: 'soc.religion.christian',
#  111: 'soc.religion.christian',
#  112: 'soc.religion.christian',
#  113: 'soc.religion.christian',
#  114: 'comp.graphics',
#  115: 'comp.graphics',
#  116: 'soc.religion.christian',
#  117: 'soc.religion.christian',
#  118: 'soc.religion.christian',
#  119: 'comp.graphics',
#  120: 'soc.religion.christian',
#  121: 'soc.religion.christian',
#  122: 'comp.graphics',
#  123: 'soc.religion.christian',
#  124: 'soc.religion.christian',
#  125: 'soc.religion.christian',
#  126: 'soc.religion.christian',
#  127: 'soc.religion.christian',
#  128: 'soc.religion.christian',
#  129: 'comp.graphics',
#  130: 'soc.religion.christian',
#  131: 'soc.religion.christian',
#  132: 'soc.religion.christian',
#  133: 'soc.religion.christian',
#  134: 'soc.religion.christian',
#  135: 'comp.graphics',
#  136: 'soc.religion.christian',
#  137: 'soc.religion.christian',
#  138: 'soc.religion.christian',
#  139: 'soc.religion.christian',
#  140: 'comp.graphics',
#  141: 'comp.graphics',
#  142: 'comp.graphics',
#  143: 'comp.graphics',
#  144: 'comp.graphics',
#  145: 'comp.graphics',
#  146: 'comp.graphics',
#  147: 'comp.graphics',
#  148: 'soc.religion.christian',
#  149: 'comp.graphics',
#  150: 'soc.religion.christian',
#  151: 'soc.religion.christian',
#  152: 'comp.graphics',
#  153: 'soc.religion.christian',
#  154: 'comp.graphics',
#  155: 'soc.religion.christian',
#  156: 'soc.religion.christian',
#  157: 'comp.graphics',
#  158: 'comp.graphics',
#  159: 'comp.graphics',
#  160: 'comp.graphics',
#  161: 'comp.graphics',
#  162: 'soc.religion.christian',
#  163: 'comp.graphics',
#  164: 'soc.religion.christian',
#  165: 'comp.graphics',
#  166: 'comp.graphics',
#  167: 'comp.graphics',
#  168: 'soc.religion.christian',
#  169: 'comp.graphics',
#  170: 'comp.graphics',
#  171: 'soc.religion.christian',
#  172: 'comp.graphics',
#  173: 'soc.religion.christian',
#  174: 'comp.graphics',
#  175: 'comp.graphics',
#  176: 'comp.graphics',
#  177: 'soc.religion.christian',
#  178: 'comp.graphics',
#  179: 'soc.religion.christian',
#  180: 'comp.graphics',
#  181: 'comp.graphics',
#  182: 'soc.religion.christian',
#  183: 'soc.religion.christian',
#  184: 'comp.graphics',
#  185: 'soc.religion.christian',
#  186: 'soc.religion.christian',
#  187: 'soc.religion.christian',
#  188: 'soc.religion.christian',
#  189: 'soc.religion.christian',
#  190: 'soc.religion.christian',
#  191: 'soc.religion.christian',
#  192: 'soc.religion.christian',
#  193: 'comp.graphics',
#  194: 'soc.religion.christian',
#  195: 'comp.graphics',
#  196: 'soc.religion.christian',
#  197: 'comp.graphics',
#  198: 'comp.graphics',
#  199: 'comp.graphics',
#  200: 'soc.religion.christian',
#  201: 'comp.graphics',
#  202: 'soc.religion.christian',
#  203: 'comp.graphics',
#  204: 'soc.religion.christian',
#  205: 'soc.religion.christian',
#  206: 'soc.religion.christian',
#  207: 'soc.religion.christian',
#  208: 'comp.graphics',
#  209: 'soc.religion.christian',
#  210: 'comp.graphics',
#  211: 'soc.religion.christian',
#  212: 'soc.religion.christian',
#  213: 'soc.religion.christian',
#  214: 'comp.graphics',
#  215: 'soc.religion.christian',
#  216: 'comp.graphics',
#  217: 'comp.graphics',
#  218: 'comp.graphics',
#  219: 'comp.graphics',
#  220: 'comp.graphics',
#  221: 'comp.graphics',
#  222: 'comp.graphics',
#  223: 'soc.religion.christian',
#  224: 'comp.graphics',
#  225: 'comp.graphics',
#  226: 'comp.graphics',
#  227: 'soc.religion.christian',
#  228: 'soc.religion.christian',
#  229: 'soc.religion.christian',
#  230: 'comp.graphics',
#  231: 'soc.religion.christian',
#  232: 'soc.religion.christian',
#  233: 'soc.religion.christian',
#  234: 'comp.graphics',
#  235: 'soc.religion.christian',
#  236: 'soc.religion.christian',
#  237: 'soc.religion.christian',
#  238: 'soc.religion.christian',
#  239: 'comp.graphics',
#  240: 'soc.religion.christian',
#  241: 'comp.graphics',
#  242: 'soc.religion.christian',
#  243: 'comp.graphics',
#  244: 'soc.religion.christian',
#  245: 'comp.graphics',
#  246: 'comp.graphics',
#  247: 'soc.religion.christian',
#  248: 'soc.religion.christian',
#  249: 'comp.graphics',
#  250: 'comp.graphics',
#  251: 'soc.religion.christian',
#  252: 'soc.religion.christian',
#  253: 'soc.religion.christian',
#  254: 'soc.religion.christian',
#  255: 'soc.religion.christian',
#  256: 'comp.graphics',
#  257: 'comp.graphics',
#  258: 'soc.religion.christian',
#  259: 'comp.graphics',
#  260: 'soc.religion.christian',
#  261: 'comp.graphics',
#  262: 'soc.religion.christian',
#  263: 'comp.graphics',
#  264: 'comp.graphics',
#  265: 'soc.religion.christian',
#  266: 'comp.graphics',
#  267: 'comp.graphics',
#  268: 'comp.graphics',
#  269: 'comp.graphics',
#  270: 'comp.graphics',
#  271: 'soc.religion.christian',
#  272: 'comp.graphics',
#  273: 'soc.religion.christian',
#  274: 'soc.religion.christian',
#  275: 'comp.graphics',
#  276: 'comp.graphics',
#  277: 'soc.religion.christian',
#  278: 'soc.religion.christian',
#  279: 'comp.graphics',
#  280: 'soc.religion.christian',
#  281: 'soc.religion.christian',
#  282: 'comp.graphics',
#  283: 'comp.graphics',
#  284: 'soc.religion.christian',
#  285: 'soc.religion.christian',
#  286: 'comp.graphics',
#  287: 'soc.religion.christian',
#  288: 'comp.graphics',
#  289: 'soc.religion.christian',
#  290: 'soc.religion.christian',
#  291: 'soc.religion.christian',
#  292: 'comp.graphics',
#  293: 'comp.graphics',
#  294: 'soc.religion.christian',
#  295: 'soc.religion.christian',
#  296: 'soc.religion.christian',
#  297: 'comp.graphics',
#  298: 'soc.religion.christian',
#  299: 'comp.graphics',
#  300: 'comp.graphics',
#  301: 'comp.graphics',
#  302: 'soc.religion.christian',
#  303: 'comp.graphics',
#  304: 'comp.graphics',
#  305: 'soc.religion.christian',
#  306: 'soc.religion.christian',
#  307: 'comp.graphics',
#  308: 'comp.graphics',
#  309: 'comp.graphics',
#  310: 'soc.religion.christian',
#  311: 'comp.graphics',
#  312: 'comp.graphics',
#  313: 'soc.religion.christian',
#  314: 'soc.religion.christian',
#  315: 'comp.graphics',
#  316: 'comp.graphics',
#  317: 'soc.religion.christian',
#  318: 'comp.graphics',
#  319: 'soc.religion.christian',
#  320: 'soc.religion.christian',
#  321: 'soc.religion.christian',
#  322: 'soc.religion.christian',
#  323: 'comp.graphics',
#  324: 'comp.graphics',
#  325: 'soc.religion.christian',
#  326: 'comp.graphics',
#  327: 'soc.religion.christian',
#  328: 'comp.graphics',
#  329: 'comp.graphics',
#  330: 'soc.religion.christian',
#  331: 'soc.religion.christian',
#  332: 'comp.graphics',
#  333: 'comp.graphics',
#  334: 'soc.religion.christian',
#  335: 'comp.graphics',
#  336: 'soc.religion.christian',
#  337: 'soc.religion.christian',
#  338: 'comp.graphics',
#  339: 'soc.religion.christian',
#  340: 'comp.graphics',
#  341: 'comp.graphics',
#  342: 'soc.religion.christian',
#  343: 'comp.graphics',
#  344: 'comp.graphics',
#  345: 'soc.religion.christian',
#  346: 'soc.religion.christian',
#  347: 'comp.graphics',
#  348: 'soc.religion.christian',
#  349: 'comp.graphics',
#  350: 'soc.religion.christian',
#  351: 'soc.religion.christian',
#  352: 'comp.graphics',
#  353: 'soc.religion.christian',
#  354: 'comp.graphics',
#  355: 'comp.graphics',
#  356: 'soc.religion.christian',
#  357: 'comp.graphics',
#  358: 'soc.religion.christian',
#  359: 'soc.religion.christian',
#  360: 'comp.graphics',
#  361: 'comp.graphics',
#  362: 'comp.graphics',
#  363: 'soc.religion.christian',
#  364: 'comp.graphics',
#  365: 'comp.graphics',
#  366: 'soc.religion.christian',
#  367: 'soc.religion.christian',
#  368: 'soc.religion.christian',
#  369: 'soc.religion.christian',
#  370: 'comp.graphics',
#  371: 'soc.religion.christian',
#  372: 'soc.religion.christian',
#  373: 'soc.religion.christian',
#  374: 'comp.graphics',
#  375: 'soc.religion.christian',
#  376: 'comp.graphics',
#  377: 'soc.religion.christian',
#  378: 'soc.religion.christian',
#  379: 'soc.religion.christian',
#  380: 'comp.graphics',
#  381: 'comp.graphics',
#  382: 'comp.graphics',
#  383: 'comp.graphics',
#  384: 'comp.graphics',
#  385: 'soc.religion.christian',
#  386: 'comp.graphics',
#  387: 'soc.religion.christian',
#  388: 'comp.graphics',
#  389: 'comp.graphics',
#  390: 'comp.graphics',
#  391: 'comp.graphics',
#  392: 'soc.religion.christian',
#  393: 'soc.religion.christian',
#  394: 'comp.graphics',
#  395: 'comp.graphics',
#  396: 'comp.graphics',
#  397: 'soc.religion.christian',
#  398: 'soc.religion.christian',
#  399: 'soc.religion.christian',
#  400: 'soc.religion.christian',
#  401: 'soc.religion.christian',
#  402: 'soc.religion.christian',
#  403: 'soc.religion.christian',
#  404: 'soc.religion.christian',
#  405: 'comp.graphics',
#  406: 'soc.religion.christian',
#  407: 'soc.religion.christian',
#  408: 'soc.religion.christian',
#  409: 'soc.religion.christian',
#  410: 'comp.graphics',
#  411: 'soc.religion.christian',
#  412: 'comp.graphics',
#  413: 'comp.graphics',
#  414: 'soc.religion.christian',
#  415: 'comp.graphics',
#  416: 'soc.religion.christian',
#  417: 'soc.religion.christian',
#  418: 'soc.religion.christian',
#  419: 'comp.graphics',
#  420: 'soc.religion.christian',
#  421: 'soc.religion.christian',
#  422: 'soc.religion.christian',
#  423: 'comp.graphics',
#  424: 'comp.graphics',
#  425: 'comp.graphics',
#  426: 'comp.graphics',
#  427: 'comp.graphics',
#  428: 'soc.religion.christian',
#  429: 'soc.religion.christian',
#  430: 'soc.religion.christian',
#  431: 'comp.graphics',
#  432: 'comp.graphics',
#  433: 'soc.religion.christian',
#  434: 'comp.graphics',
#  435: 'soc.religion.christian',
#  436: 'soc.religion.christian',
#  437: 'soc.religion.christian',
#  438: 'comp.graphics',
#  439: 'soc.religion.christian',
#  440: 'soc.religion.christian',
#  441: 'comp.graphics',
#  442: 'comp.graphics',
#  443: 'soc.religion.christian',
#  444: 'comp.graphics',
#  445: 'soc.religion.christian',
#  446: 'soc.religion.christian',
#  447: 'soc.religion.christian',
#  448: 'soc.religion.christian',
#  449: 'soc.religion.christian',
#  450: 'soc.religion.christian',
#  451: 'soc.religion.christian',
#  452: 'soc.religion.christian',
#  453: 'soc.religion.christian',
#  454: 'soc.religion.christian',
#  455: 'comp.graphics',
#  456: 'comp.graphics',
#  457: 'soc.religion.christian',
#  458: 'comp.graphics',
#  459: 'soc.religion.christian',
#  460: 'soc.religion.christian',
#  461: 'comp.graphics',
#  462: 'soc.religion.christian',
#  463: 'soc.religion.christian',
#  464: 'comp.graphics',
#  465: 'comp.graphics',
#  466: 'comp.graphics',
#  467: 'soc.religion.christian',
#  468: 'comp.graphics',
#  469: 'soc.religion.christian',
#  470: 'comp.graphics',
#  471: 'soc.religion.christian',
#  472: 'soc.religion.christian',
#  473: 'comp.graphics',
#  474: 'soc.religion.christian',
#  475: 'comp.graphics',
#  476: 'soc.religion.christian',
#  477: 'comp.graphics',
#  478: 'comp.graphics',
#  479: 'soc.religion.christian',
#  480: 'soc.religion.christian',
#  481: 'comp.graphics',
#  482: 'comp.graphics',
#  483: 'soc.religion.christian',
#  484: 'soc.religion.christian',
#  485: 'soc.religion.christian',
#  486: 'comp.graphics',
#  487: 'soc.religion.christian',
#  488: 'soc.religion.christian',
#  489: 'soc.religion.christian',
#  490: 'soc.religion.christian',
#  491: 'comp.graphics',
#  492: 'soc.religion.christian',
#  493: 'soc.religion.christian',
#  494: 'soc.religion.christian',
#  495: 'soc.religion.christian',
#  496: 'soc.religion.christian',
#  497: 'soc.religion.christian',
#  498: 'soc.religion.christian',
#  499: 'comp.graphics',
#  500: 'soc.religion.christian',
#  501: 'comp.graphics',
#  502: 'soc.religion.christian',
#  503: 'comp.graphics',
#  504: 'comp.graphics',
#  505: 'comp.graphics',
#  506: 'comp.graphics',
#  507: 'soc.religion.christian',
#  508: 'soc.religion.christian',
#  509: 'comp.graphics',
#  510: 'comp.graphics',
#  511: 'comp.graphics',
#  512: 'comp.graphics',
#  513: 'soc.religion.christian',
#  514: 'comp.graphics',
#  515: 'comp.graphics',
#  516: 'comp.graphics',
#  517: 'comp.graphics',
#  518: 'soc.religion.christian',
#  519: 'comp.graphics',
#  520: 'comp.graphics',
#  521: 'comp.graphics',
#  522: 'comp.graphics',
#  523: 'soc.religion.christian',
#  524: 'comp.graphics',
#  525: 'comp.graphics',
#  526: 'soc.religion.christian',
#  527: 'comp.graphics',
#  528: 'comp.graphics',
#  529: 'comp.graphics',
#  530: 'comp.graphics',
#  531: 'soc.religion.christian',
#  532: 'comp.graphics',
#  533: 'soc.religion.christian',
#  534: 'comp.graphics',
#  535: 'soc.religion.christian',
#  536: 'soc.religion.christian',
#  537: 'soc.religion.christian',
#  538: 'soc.religion.christian',
#  539: 'soc.religion.christian',
#  540: 'comp.graphics',
#  541: 'soc.religion.christian',
#  542: 'soc.religion.christian',
#  543: 'soc.religion.christian',
#  544: 'soc.religion.christian',
#  545: 'comp.graphics',
#  546: 'soc.religion.christian',
#  547: 'comp.graphics',
#  548: 'comp.graphics',
#  549: 'comp.graphics',
#  550: 'soc.religion.christian',
#  551: 'comp.graphics',
#  552: 'soc.religion.christian',
#  553: 'soc.religion.christian',
#  554: 'comp.graphics',
#  555: 'comp.graphics',
#  556: 'soc.religion.christian',
#  557: 'soc.religion.christian',
#  558: 'comp.graphics',
#  559: 'soc.religion.christian',
#  560: 'soc.religion.christian',
#  561: 'soc.religion.christian',
#  562: 'soc.religion.christian',
#  563: 'comp.graphics',
#  564: 'soc.religion.christian',
#  565: 'soc.religion.christian',
#  566: 'soc.religion.christian',
#  567: 'comp.graphics',
#  568: 'comp.graphics',
#  569: 'soc.religion.christian',
#  570: 'comp.graphics',
#  571: 'comp.graphics',
#  572: 'comp.graphics',
#  573: 'comp.graphics',
#  574: 'comp.graphics',
#  575: 'comp.graphics',
#  576: 'soc.religion.christian',
#  577: 'soc.religion.christian',
#  578: 'comp.graphics',
#  579: 'soc.religion.christian',
#  580: 'soc.religion.christian',
#  581: 'comp.graphics',
#  582: 'soc.religion.christian',
#  583: 'soc.religion.christian',
#  584: 'comp.graphics',
#  585: 'comp.graphics',
#  586: 'soc.religion.christian',
#  587: 'soc.religion.christian',
#  588: 'soc.religion.christian',
#  589: 'comp.graphics',
#  590: 'comp.graphics',
#  591: 'soc.religion.christian',
#  592: 'comp.graphics',
#  593: 'comp.graphics',
#  594: 'soc.religion.christian',
#  595: 'comp.graphics',
#  596: 'comp.graphics',
#  597: 'soc.religion.christian',
#  598: 'comp.graphics',
#  599: 'soc.religion.christian',
#  600: 'comp.graphics',
#  601: 'comp.graphics',
#  602: 'comp.graphics',
#  603: 'soc.religion.christian',
#  604: 'comp.graphics',
#  605: 'comp.graphics',
#  606: 'soc.religion.christian',
#  607: 'soc.religion.christian',
#  608: 'soc.religion.christian',
#  609: 'soc.religion.christian',
#  610: 'soc.religion.christian',
#  611: 'soc.religion.christian',
#  612: 'comp.graphics',
#  613: 'soc.religion.christian',
#  614: 'soc.religion.christian',
#  615: 'comp.graphics',
#  616: 'soc.religion.christian',
#  617: 'comp.graphics',
#  618: 'comp.graphics',
#  619: 'soc.religion.christian',
#  620: 'comp.graphics',
#  621: 'soc.religion.christian',
#  622: 'comp.graphics',
#  623: 'soc.religion.christian',
#  624: 'comp.graphics',
#  625: 'comp.graphics',
#  626: 'soc.religion.christian',
#  627: 'comp.graphics',
#  628: 'soc.religion.christian',
#  629: 'comp.graphics',
#  630: 'comp.graphics',
#  631: 'soc.religion.christian',
#  632: 'comp.graphics',
#  633: 'soc.religion.christian',
#  634: 'soc.religion.christian',
#  635: 'comp.graphics',
#  636: 'soc.religion.christian',
#  637: 'soc.religion.christian',
#  638: 'comp.graphics',
#  639: 'soc.religion.christian',
#  640: 'soc.religion.christian',
#  641: 'soc.religion.christian',
#  642: 'comp.graphics',
#  643: 'soc.religion.christian',
#  644: 'soc.religion.christian',
#  645: 'comp.graphics',
#  646: 'soc.religion.christian',
#  647: 'soc.religion.christian',
#  648: 'comp.graphics',
#  649: 'soc.religion.christian',
#  650: 'comp.graphics',
#  651: 'soc.religion.christian',
#  652: 'comp.graphics',
#  653: 'comp.graphics',
#  654: 'comp.graphics',
#  655: 'soc.religion.christian',
#  656: 'soc.religion.christian',
#  657: 'comp.graphics',
#  658: 'soc.religion.christian',
#  659: 'comp.graphics',
#  660: 'soc.religion.christian',
#  661: 'soc.religion.christian',
#  662: 'soc.religion.christian',
#  663: 'soc.religion.christian',
#  664: 'comp.graphics',
#  665: 'comp.graphics',
#  666: 'comp.graphics',
#  667: 'comp.graphics',
#  668: 'comp.graphics',
#  669: 'soc.religion.christian',
#  670: 'comp.graphics',
#  671: 'soc.religion.christian',
#  672: 'comp.graphics',
#  673: 'comp.graphics',
#  674: 'soc.religion.christian',
#  675: 'soc.religion.christian',
#  676: 'soc.religion.christian',
#  677: 'soc.religion.christian',
#  678: 'comp.graphics',
#  679: 'comp.graphics',
#  680: 'soc.religion.christian',
#  681: 'soc.religion.christian',
#  682: 'comp.graphics',
#  683: 'soc.religion.christian',
#  684: 'comp.graphics',
#  685: 'soc.religion.christian',
#  686: 'soc.religion.christian',
#  687: 'comp.graphics',
#  688: 'comp.graphics',
#  689: 'soc.religion.christian',
#  690: 'soc.religion.christian',
#  691: 'comp.graphics',
#  692: 'soc.religion.christian',
#  693: 'comp.graphics',
#  694: 'comp.graphics',
#  695: 'soc.religion.christian',
#  696: 'soc.religion.christian',
#  697: 'soc.religion.christian',
#  698: 'comp.graphics',
#  699: 'comp.graphics',
#  700: 'comp.graphics',
#  701: 'soc.religion.christian',
#  702: 'comp.graphics',
#  703: 'comp.graphics',
#  704: 'soc.religion.christian',
#  705: 'comp.graphics',
#  706: 'comp.graphics',
#  707: 'soc.religion.christian',
#  708: 'comp.graphics',
#  709: 'comp.graphics',
#  710: 'comp.graphics',
#  711: 'soc.religion.christian',
#  712: 'comp.graphics',
#  713: 'soc.religion.christian',
#  714: 'soc.religion.christian',
#  715: 'comp.graphics',
#  716: 'soc.religion.christian',
#  717: 'comp.graphics',
#  718: 'soc.religion.christian',
#  719: 'soc.religion.christian',
#  720: 'comp.graphics',
#  721: 'soc.religion.christian',
#  722: 'soc.religion.christian',
#  723: 'comp.graphics',
#  724: 'comp.graphics',
#  725: 'comp.graphics',
#  726: 'soc.religion.christian',
#  727: 'soc.religion.christian',
#  728: 'comp.graphics',
#  729: 'comp.graphics',
#  730: 'comp.graphics',
#  731: 'soc.religion.christian',
#  732: 'comp.graphics',
#  733: 'soc.religion.christian',
#  734: 'comp.graphics',
#  735: 'comp.graphics',
#  736: 'comp.graphics',
#  737: 'comp.graphics',
#  738: 'comp.graphics',
#  739: 'soc.religion.christian',
#  740: 'comp.graphics',
#  741: 'soc.religion.christian',
#  742: 'comp.graphics',
#  743: 'comp.graphics',
#  744: 'comp.graphics',
#  745: 'soc.religion.christian',
#  746: 'comp.graphics',
#  747: 'comp.graphics',
#  748: 'comp.graphics',
#  749: 'soc.religion.christian',
#  750: 'comp.graphics',
#  751: 'comp.graphics',
#  752: 'comp.graphics',
#  753: 'soc.religion.christian',
#  754: 'soc.religion.christian',
#  755: 'soc.religion.christian',
#  756: 'comp.graphics',
#  757: 'soc.religion.christian',
#  758: 'soc.religion.christian',
#  759: 'comp.graphics',
#  760: 'comp.graphics',
#  761: 'comp.graphics',
#  762: 'soc.religion.christian',
#  763: 'soc.religion.christian',
#  764: 'soc.religion.christian',
#  765: 'soc.religion.christian',
#  766: 'soc.religion.christian',
#  767: 'comp.graphics',
#  768: 'soc.religion.christian',
#  769: 'soc.religion.christian',
#  770: 'comp.graphics',
#  771: 'soc.religion.christian',
#  772: 'comp.graphics',
#  773: 'soc.religion.christian',
#  774: 'comp.graphics',
#  775: 'comp.graphics',
#  776: 'comp.graphics',
#  777: 'comp.graphics',
#  778: 'soc.religion.christian',
#  779: 'comp.graphics',
#  780: 'comp.graphics',
#  781: 'comp.graphics',
#  782: 'comp.graphics',
#  783: 'soc.religion.christian',
#  784: 'soc.religion.christian',
#  785: 'comp.graphics',
#  786: 'comp.graphics'}

# %%
#form TF-IDF term-document matrix
tfidf_vect = TfidfVectorizer()
X_tfidf = tfidf_vect.fit_transform(twenty_train.data)
X_tfidf
# Out:
# <787x20868 sparse matrix of type '<class 'numpy.float64'>'
# 	with 136994 stored elements in Compressed Sparse Row format>

# %%
#extract vertex-hyperedge incidences and weights from TFIDF matrix
mat = coo_matrix(X_tfidf)
edges = mat.col
nodes = mat.row
data = np.array([edges,nodes]).T
weights = mat.data

h = hnx.Hypergraph.from_incidence_matrix(mat)

# %%
#check the hypergraph is connected, as this is required by spectral clustering
#if not, restrict to largest connected component or modify hypergraph as necessary
h.is_connected()
# Out:
# True

# %%
#the weighted incidence matrix which contain the cell weights
I,verMap,edgeMap = h.incidence_matrix(weights=True,index=True)
I
# Out:
# <787x20868 sparse matrix of type '<class 'numpy.float64'>'
# 	with 136994 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Cluster with weights

# %%
#cluster the vertices (documents)
num_clus=len(categories)
clusters=hnx.spec_clus(h,num_clus,weights=True)   ### set flag for weights here
print([len(v) for v in clusters.values()])

#visualize document category composition within each cluster
fig = plt.figure(figsize=(22, 10))
labels=sorted(list(set(doc_types.values())))
colors=['#e41a1c','#377eb8']

#pie charts
for clus in range(num_clus):
    ax=plt.subplot(131+clus)
    counts=[[doc_types[y] for y in clusters[clus]].count(z) for z in labels]
    ax.pie(counts, colors=colors, shadow=True, startangle=90)
    ax.set_title("Cluster "+repr(clus)+ "\n"+ repr(sum(counts))+ ' Documents',fontsize=20)

#legend
ax=plt.subplot(131+num_clus)
patches = [mpatches.Patch(color=color, label=label)
    for label, color in zip(labels, colors)]
ax.legend(patches, labels, loc='center',fontsize=20, frameon=False)
ax.axis('off');
# Out:
# [383, 404]

# %% [markdown]
# ## Cluster without weights

# %%
#cluster the vertices (documents)
num_clus=len(categories)
clusters=hnx.spec_clus(h,num_clus,weights=False)   ### set flag for weights here
print([len(v) for v in clusters.values()])

#visualize document category composition within each cluster
fig = plt.figure(figsize=(22, 10))
labels=sorted(list(set(doc_types.values())))
colors=['#e41a1c','#377eb8']

#pie charts
for clus in range(num_clus):
    ax=plt.subplot(131+clus)
    counts=[[doc_types[y] for y in clusters[clus]].count(z) for z in labels]
    ax.pie(counts, colors=colors, shadow=True, startangle=90)
    ax.set_title("Cluster "+repr(clus)+ "\n"+ repr(sum(counts))+ ' Documents',fontsize=20)

#legend
ax=plt.subplot(131+num_clus)
patches = [mpatches.Patch(color=color, label=label)
    for label, color in zip(labels, colors)]
ax.legend(patches, labels, loc='center',fontsize=20, frameon=False)
ax.axis('off');
# Out:
# [382, 405]
