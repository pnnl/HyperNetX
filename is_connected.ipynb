# %%
import random
from hypernetx import EntitySet, Hypergraph
import numpy as np
from collections import OrderedDict
import time
import pandas as pd
import hypernetx as hnx
import hypernetx.utils.read_write as read_write
from hypernetx.utils.toys import TransmissionProblem

# %%
n = 1000
m = 10000
hyperedgeList = [set(random.sample(range(n), k=random.choice(range(2,10)))) for i in range(m)]
h = Hypergraph(hyperedgeList)

# %%
start = time.time()

s = 3
gc = set()
node = random.choice(list(h.nodes))

gc.add(node)
unique_neighbors = set(h.neighbors(node, s)).difference(gc)

while len(gc) < h.number_of_nodes() and len(unique_neighbors) > 0:
    newNodes = unique_neighbors
    unique_neighbors = set()
    for node in newNodes:
        unique_neighbors.update(h.neighbors(node, s))
    
    unique_neighbors = unique_neighbors.difference(gc)
    print(len(unique_neighbors))
    gc = gc.union(unique_neighbors)

if len(gc) == h.number_of_nodes():
    print("true")
else:
    print("false")
print(time.time() - start)
# Out:
# false
# 0.0008909702301025391

# %%
start = time.time()
# component_sizes = list()
components = list()
s = 6

nodes = set(h.nodes)

while len(nodes) > 0:
    gc = set()
    node = random.choice(list(nodes))

    gc.add(node)
    unique_neighbors = set(h.neighbors(node, s)).difference(gc)

    while len(gc) < h.number_of_nodes() and len(unique_neighbors) > 0:
        newNodes = unique_neighbors
        unique_neighbors = set()
        for node in newNodes:
            unique_neighbors.update(h.neighbors(node, s))
        
        unique_neighbors = unique_neighbors.difference(gc)
        gc = gc.union(unique_neighbors)
    nodes = nodes.difference(gc)
    # component_sizes.append(len(gc))
    components.append(set(gc))
dist = [len(c) for c in components]
print(time.time() - start)
print(sorted(dist))
# Out:
# 0.18120718002319336
# ...

# %%
start = time.time()
components = h.s_connected_components(s=s, edges=False, return_singletons=True)
dist = [len(c) for c in components]
print(time.time() - start)
print(sorted(dist))
# Out:
# 0.10702896118164062
# ...
